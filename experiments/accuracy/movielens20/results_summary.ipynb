# %%
import json
import os
import pandas as pd

# %%
dicts = []
for p in os.listdir("results"):
    dicts.append(json.load(open(f"results/{p}")))

m = []
d = []
r20 = []
r50 = []
n100 = []
train_time = []
for di in dicts:
    if di["model"]["general"]["model"] == "EASE":
        m.append(di["model"]["general"]["model"])
        d.append(100)
    elif di["model"]["general"]["model"] == "MRF":
        m.append(di["model"]["general"]["model"] + f" (r={di['model']['model_specific']['rr']:.1f})")
        d.append(round(100*di["performance"]["memory"]["density"],1))
    elif di["model"]["general"]["model"] == "SANSA":
        d.append(round(100*2*di["model"]["model_specific"]["target_density"],1))
        m.append(di["model"]["general"]["model"])
    else:
        raise ValueError("Unknown model")
    r20.append(round(di["results"]["20"]["recall"]["mean"],3))
    r50.append(round(di["results"]["50"]["recall"]["mean"],3))
    n100.append(round(di["results"]["100"]["ndcg"]["mean"],3))
    train_time.append(round(di["performance"]["time"]["construct_weights_time"],2))


df = pd.DataFrame(
    {
        "model": m,
        "d (%)": d,
        "r@20": r20,
        "r@50": r50,
        "n@100": n100,
        "train (s)": train_time,
    }
)

df = df.sort_values(by=["d (%)", "model"], ascending=[True, True]).reset_index(drop=True)

# %%
df
# Out:
#           model  d (%)   r@20   r@50  n@100  train (s)
# 0         SANSA    0.2  0.377  0.501  0.405      41.87
# 1   MRF (r=0.0)    0.5  0.390  0.515  0.420      48.90
# 2   MRF (r=0.1)    0.5  0.384  0.511  0.415      22.14
# 3   MRF (r=0.5)    0.5  0.380  0.508  0.412      21.14
# 4         SANSA    0.5  0.383  0.512  0.413      48.84
# 5   MRF (r=0.0)    1.0  0.390  0.516  0.420      96.38
# 6   MRF (r=0.1)    1.0  0.387  0.515  0.418      36.93
# 7   MRF (r=0.5)    1.0  0.385  0.513  0.416      32.38
# 8         SANSA    1.0  0.387  0.516  0.417      63.93
# 9   MRF (r=0.0)    2.0  0.390  0.516  0.420     208.28
# 10  MRF (r=0.1)    2.0  0.389  0.516  0.420      80.02
# 11  MRF (r=0.5)    2.0  0.386  0.515  0.418      71.86
# 12        SANSA    2.0  0.388  0.518  0.420      99.54
# 13         EASE  100.0  0.392  0.521  0.422      43.52
