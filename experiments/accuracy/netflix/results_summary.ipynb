# %%
import json
import os
import pandas as pd

# %%
dicts = []
for p in os.listdir("results"):
    dicts.append(json.load(open(f"results/{p}")))

m = []
d = []
r20 = []
r50 = []
n100 = []
train_time = []
for di in dicts:
    if di["model"]["general"]["model"] == "EASE":
        m.append(di["model"]["general"]["model"])
        d.append(100)
    elif di["model"]["general"]["model"] == "MRF":
        m.append(di["model"]["general"]["model"] + f" (r={di['model']['model_specific']['rr']:.1f})")
        d.append(round(100*di["performance"]["memory"]["density"],1))
    elif di["model"]["general"]["model"] == "SANSA":
        d.append(round(100*2*di["model"]["model_specific"]["target_density"],1))
        m.append(di["model"]["general"]["model"])
    else:
        raise ValueError("Unknown model")
    r20.append(round(di["results"]["20"]["recall"]["mean"],3))
    r50.append(round(di["results"]["50"]["recall"]["mean"],3))
    n100.append(round(di["results"]["100"]["ndcg"]["mean"],3))
    train_time.append(round(di["performance"]["time"]["construct_weights_time"],2))


df = pd.DataFrame(
    {
        "model": m,
        "d (%)": d,
        "r@20": r20,
        "r@50": r50,
        "n@100": n100,
        "train (s)": train_time,
    }
)

df = df.sort_values(by=["d (%)", "model"], ascending=[True, True]).reset_index(drop=True)

# %%
df
# Out:
#           model  d (%)   r@20   r@50  n@100  train (s)
# 0   MRF (r=0.0)    0.5  0.360  0.441  0.391      58.54
# 1   MRF (r=0.1)    0.5  0.358  0.439  0.389      36.95
# 2   MRF (r=0.5)    0.5  0.352  0.435  0.385      31.10
# 3         SANSA    0.5  0.354  0.433  0.383      77.56
# 4   MRF (r=0.0)    1.0  0.362  0.442  0.392      97.40
# 5   MRF (r=0.1)    1.0  0.360  0.441  0.391      60.64
# 6   MRF (r=0.5)    1.0  0.357  0.439  0.389      52.46
# 7         SANSA    1.0  0.354  0.435  0.384      83.08
# 8   MRF (r=0.0)    2.0  0.362  0.443  0.392     193.46
# 9   MRF (r=0.1)    2.0  0.361  0.443  0.392     135.01
# 10  MRF (r=0.5)    2.0  0.359  0.442  0.391     135.60
# 11        SANSA    2.0  0.356  0.438  0.386      94.86
# 12         EASE  100.0  0.362  0.444  0.393      38.72
