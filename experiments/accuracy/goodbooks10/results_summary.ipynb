# %%
import json
import os
import pandas as pd

# %%
dicts = []
for p in os.listdir("results"):
    dicts.append(json.load(open(f"results/{p}")))

m = []
d = []
r20 = []
r50 = []
n100 = []
train_time = []
for di in dicts:
    if di["model"]["general"]["model"] == "EASE":
        m.append(di["model"]["general"]["model"])
        d.append(100)
    elif di["model"]["general"]["model"] == "MRF":
        m.append(di["model"]["general"]["model"] + f" (r={di['model']['model_specific']['rr']:.1f})")
        d.append(round(100*di["performance"]["memory"]["density"],1))
    elif di["model"]["general"]["model"] == "SANSA":
        d.append(round(100*2*di["model"]["model_specific"]["target_density"],1))
        m.append(di["model"]["general"]["model"])
    else:
        raise ValueError("Unknown model")
    r20.append(round(di["results"]["20"]["recall"]["mean"],3))
    r50.append(round(di["results"]["50"]["recall"]["mean"],3))
    n100.append(round(di["results"]["100"]["ndcg"]["mean"],3))
    train_time.append(round(di["performance"]["time"]["construct_weights_time"],2))


df = pd.DataFrame(
    {
        "model": m,
        "d (%)": d,
        "r@20": r20,
        "r@50": r50,
        "n@100": n100,
        "train (s)": train_time,
    }
)

df = df.sort_values(by=["d (%)", "model"], ascending=[True, True]).reset_index(drop=True)

# %%
df
# Out:
#           model  d (%)   r@20   r@50  n@100  train (s)
# 0         SANSA    0.1  0.341  0.471  0.475      13.51
# 1         SANSA    0.2  0.351  0.485  0.491      12.65
# 2   MRF (r=0.0)    0.5  0.364  0.497  0.507       6.09
# 3   MRF (r=0.1)    0.5  0.357  0.493  0.500       4.49
# 4   MRF (r=0.5)    0.5  0.350  0.488  0.490       4.11
# 5         SANSA    0.5  0.355  0.493  0.499      12.41
# 6   MRF (r=0.0)    1.0  0.363  0.501  0.508      10.70
# 7   MRF (r=0.1)    1.0  0.358  0.495  0.501       6.42
# 8   MRF (r=0.5)    1.0  0.352  0.492  0.493       6.29
# 9         SANSA    1.0  0.356  0.495  0.500      14.79
# 10  MRF (r=0.0)    2.0  0.363  0.501  0.507      25.89
# 11  MRF (r=0.1)    2.0  0.359  0.496  0.502      11.38
# 12  MRF (r=0.5)    2.0  0.354  0.493  0.495      11.14
# 13        SANSA    2.0  0.356  0.498  0.501      19.49
# 14         EASE  100.0  0.357  0.494  0.499       6.03
